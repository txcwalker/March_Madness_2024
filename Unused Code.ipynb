# %%
# Random Forest 

'''# Adding some multipliers based on Seed if needed, Currently the model works about the same with no multipliers so lets keep
# things simple

# Copy Dataframe
allgames_df3 = allgames_df2.copy()

# List of columns to exclude from below funciton
excluded_columns = ['Season', 'Conf_A', 'Luck_A', 'Seed_A', 'TeamID_A',
                    'FirstD1Season_A', 'LastD1Season_A','Conf_Tier_A', "TeamID_B", 'Seed_B', 
                    'Conf_B', 'Luck_B', 'Conf_Tier_B', 'FirstD1Season_B', 'LastD1Season_B','WinnerID','Winner'] #'RandID',
                    #  'W_A', 'L_A','W_B', 'L_B',

    # Get list of columns to multiply for _A and _B
columns_A = [col for col in allgames_df2.columns if col.endswith('_A') and col not in excluded_columns]
columns_B = [col for col in allgames_df2.columns if col.endswith('_B') and col not in excluded_columns]

# Function to determine the multiplication factor based on seed value
def get_seed_multiplier(seed):
    if seed in [1,2]:
        return 1  # No multiplication
    elif seed in [3, 4]:
        return 0.92
    elif seed >= 5 and seed <= 8:
        return 0.80
    elif seed >= 9 and seed <= 11:
        return 0.66
    else:  # seed > 12
        return 0.50

# Apply the multiplier logic for _A columns
for col in columns_A:
    seed_multiplier_A = allgames_df2['Seed_A'].apply(get_seed_multiplier)
    conf_tier_A = allgames_df2['Conf_Tier_A']
    allgames_df3[col] = allgames_df2[col] * seed_multiplier_A * (1/conf_tier_A)

# Apply the multiplier logic for _B columns
for col in columns_B:
    seed_multiplier_B = allgames_df2['Seed_B'].apply(get_seed_multiplier)
    conf_tier_B = allgames_df2['Conf_Tier_B']
    allgames_df3[col] = allgames_df2[col] * seed_multiplier_B * (1/conf_tier_B)

# Saving df locally to have and incase of debugging
allgames_df3.to_csv('data/_allgames3.csv', index = False)'''

# %%
# Random Forest

'''# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize PCA with the number of components you want (here, 31 components)
pca = PCA(n_components=29)
X_pca = pca.fit_transform(X_scaled)

# Explained variance ratio for each principal component
explained_variance = pca.explained_variance_ratio_
print("Explained Variance by Principal Component:", explained_variance)

# Scree plot
plt.figure(figsize=(10, 6))
plt.plot(range(1, 30), explained_variance, marker='o', linestyle='-', color='b')
plt.xticks(range(1, 30))
plt.xlabel("Principal Component")
plt.ylabel("Explained Variance Ratio")
plt.title("Scree Plot of Explained Variance by Principal Component")
plt.show()

# Cumulative variance plot (optional for further insight)
cumulative_variance = np.cumsum(explained_variance)
plt.figure(figsize=(10, 6))
plt.plot(range(1, 30), cumulative_variance, marker='o', linestyle='-', color='g')
plt.xticks(range(1, 30))
plt.xlabel("Principal Component")
plt.ylabel("Cumulative Explained Variance")
plt.title("Cumulative Explained Variance by Principal Component")
plt.show()
'''

# %%
# Logistic Regression is not Black Box model so below cannot and should not be used
'''# Shapley Additive Explanations (SHAP) 

# Initialize SHAP explainer
explainer = shap.LinearExplainer(log_reg, X_train)
shap_values = explainer.shap_values(X_test)

# Plot SHAP values for the first instance
shap.initjs()
shap.summary_plot(shap_values, X_test)'''

'''# Local Interpretable Model Agnositic Explanations (LIME):
explainer_lime = lime.lime_tabular.LimeTabularExplainer(
    training_data=X_train,
    feature_names=X.columns,
    mode='classification'
)

# Explain a single prediction
i = 0  # Change this index to explain different predictions
exp = explainer_lime.explain_instance(X_test[i], log_reg.predict_proba, num_features=10)

# Show the LIME explanation
exp.show_in_notebook(show_table=True)'''
